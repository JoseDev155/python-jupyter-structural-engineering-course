# %% [markdown]
# # Generacion de graficas de Lectura de registros sismicos
#
# En la Aplicacion 2 del **Taller1** realizaremos la lectura de datos de un registro sismico, para leer los datos (extraidos desde el internet o un archivo
# local) utilizaremos **numpy** y para generar la grafica de esos resultados usamos **matplotlib**.
#
# Esta Aplicacion 2 tiene como objetivo usar las diversas opciones de matplotlib para personalizar subplots
#
# * [Link 2024](http://www.cismid.uni.edu.pe/ceois/red/)
# * [Link 2025](https://www.cismid.uni.edu.pe/ceois/redacis/red/)

# %%
import numpy as np
